# %%
from stockfish import Stockfish
import chess

stockfish_path = "/Users/benitorusconi/Documents/CDS/05_HS23/Reinforcement Learning (cds-117)/engine/stockfish"
stockfish = Stockfish(path=stockfish_path)

def print_board(board):
    print(board)

def play_game():
    board = chess.Board()

    print("Chess game against Stockfish\n")

    while not board.is_game_over():
        print_board(board)

        # Player's move
        player_move = input("Your move (in algebraic notation): ")
        if chess.Move.from_uci(player_move) in board.legal_moves:
            board.push_uci(player_move)
        else:
            print("Invalid move. Try again.")
            continue

        if board.is_game_over():
            break

        # Stockfish's move
        stockfish.set_fen_position(board.fen())
        stockfish_move = stockfish.get_best_move()
        print("Stockfish's move:", stockfish_move)
        board.push_uci(stockfish_move)

    print("\nGame Over")
    print("Result:", board.result())

# Play the game
play_game()
# Out:
# Chess game against Stockfish
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# Stockfish's move: c7c5
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# Stockfish's move: c5d4
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . p P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
# Stockfish's move: d4c3
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . p . . . . .
# P P . . . P P P
# R N B Q K B N R
# Invalid move. Try again.
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . p . . . . .
# P P . . . P P P
# R N B Q K B N R
# Invalid move. Try again.
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . p . . . . .
# P P . . . P P P
# R N B Q K B N R
# Stockfish's move: c3b2
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . . . . . . Q
# . . . . P . . .
# . . . . . . . .
# P p . . . P P P
# R N B . K B N R
# Stockfish's move: b2a1q
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . . . . . . Q
# . . . . P . . .
# . . . . . . . .
# P . . . K P P P
# q N B . . B N R
# Stockfish's move: d8b6
# r n b . k b n r
# p p . p p p p p
# . q . . . . . .
# . . . . . . . Q
# . . . . P . . .
# . . . . K . . .
# P . . . . P P P
# q N B . . B N R
# Invalid move. Try again.
# r n b . k b n r
# p p . p p p p p
# . q . . . . . .
# . . . . . . . Q
# . . . . P . . .
# . . . . K . . .
# P . . . . P P P
# q N B . . B N R
# Invalid move. Try again.
# r n b . k b n r
# p p . p p p p p
# . q . . . . . .
# . . . . . . . Q
# . . . . P . . .
# . . . . K . . .
# P . . . . P P P
# q N B . . B N R
# Stockfish's move: b8c6
# r . b . k b n r
# p p . p p p p p
# . q n . . . . .
# . . . . . . . Q
# . . . . P . . .
# . . . . . K . .
# P . . . . P P P
# q N B . . B N R
# Stockfish's move: a1f6
# r . b . k b n r
# p p . p p p p Q
# . q n . . q . .
# . . . . . . . .
# . . . . P . . .
# . . . . . K . .
# P . . . . P P P
# . N B . . B N R
# Stockfish's move: b6f2
# r . b . k b n r
# p p . p p p p Q
# . . n . . q . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . K .
# P . . . . q P P
# . N B . . B N R
# Stockfish's move: f2h4
# r . b . k b n r
# p p . p p p p Q
# . . n . . q . .
# . . . . . . . .
# . . . . P . . q
# . . . . . . . K
# P . . . . . P P
# . N B . . B N R
# Stockfish's move: f6h4
#
# Game Over
# Result: 0-1
